# %% [markdown]
# # Задание 1.2 - Линейный классификатор (Linear classifier)
#
# В этом задании мы реализуем другую модель машинного обучения - линейный классификатор. Линейный классификатор подбирает для каждого класса веса, на которые нужно умножить значение каждого признака и потом сложить вместе.
# Тот класс, у которого эта сумма больше, и является предсказанием модели.
#
# В этом задании вы:
# - потренируетесь считать градиенты различных многомерных функций
# - реализуете подсчет градиентов через линейную модель и функцию потерь softmax
# - реализуете процесс тренировки линейного классификатора
# - подберете параметры тренировки на практике
#
# На всякий случай, еще раз ссылка на туториал по numpy:
# http://cs231n.github.io/python-numpy-tutorial/

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
from dataset import load_svhn, random_split_train_val
from gradient_check import check_gradient
from metrics import multiclass_accuracy 
import linear_classifer

# %% [markdown]
# # Как всегда, первым делом загружаем данные
#
# Мы будем использовать все тот же SVHN.

# %%
def prepare_for_linear_classifier(train_X, test_X):
    train_flat = train_X.reshape(train_X.shape[0], -1).astype(np.float) / 255.0
    test_flat = test_X.reshape(test_X.shape[0], -1).astype(np.float) / 255.0
    
    # Subtract mean
    mean_image = np.mean(train_flat, axis = 0)
    train_flat -= mean_image
    test_flat -= mean_image
    
    # Add another channel with ones as a bias term
    train_flat_with_ones = np.hstack([train_flat, np.ones((train_X.shape[0], 1))])
    test_flat_with_ones = np.hstack([test_flat, np.ones((test_X.shape[0], 1))])    
    return train_flat_with_ones, test_flat_with_ones
    
train_X, train_y, test_X, test_y = load_svhn("data", max_train=10000, max_test=1000)    
train_X, test_X = prepare_for_linear_classifier(train_X, test_X)
# Split train into train and val
train_X, train_y, val_X, val_y = random_split_train_val(train_X, train_y, num_val = 1000)

# %% [markdown]
# # Играемся с градиентами!
#
# В этом курсе мы будем писать много функций, которые вычисляют градиенты аналитическим методом.
#
# Все функции, в которых мы будем вычислять градиенты, будут написаны по одной и той же схеме.
# Они будут получать на вход точку, где нужно вычислить значение и градиент функции, а на выходе будут выдавать кортеж (tuple) из двух значений - собственно значения функции в этой точке (всегда одно число) и аналитического значения градиента в той же точке (той же размерности, что и вход).
# ```
# def f(x):
#     """
#     Computes function and analytic gradient at x
#
#     x: np array of float, input to the function
#
#     Returns:
#     value: float, value of the function
#     grad: np array of float, same shape as x
#     """
#     ...
#
#     return value, grad
# ```
#
# Необходимым инструментом во время реализации кода, вычисляющего градиенты, является функция его проверки. Эта функция вычисляет градиент численным методом и сверяет результат с градиентом, вычисленным аналитическим методом.
#
# Мы начнем с того, чтобы реализовать вычисление численного градиента (numeric gradient) в функции `check_gradient` в `gradient_check.py`. Эта функция будет принимать на вход функции формата, заданного выше, использовать значение `value` для вычисления численного градиента и сравнит его с аналитическим - они должны сходиться.
#
# Напишите часть функции, которая вычисляет градиент с помощью численной производной для каждой координаты. Для вычисления производной используйте так называемую two-point formula (https://en.wikipedia.org/wiki/Numerical_differentiation):
#
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/22fc2c0a66c63560a349604f8b6b39221566236d)
#
# Все функции приведенные в следующей клетке должны проходить gradient check.

# %%
# TODO: Implement check_gradient function in gradient_check.py
# All the functions below should pass the gradient check

def square(x):
    return float(x*x), 2*x

check_gradient(square, np.array([3.0]))

def array_sum(x):
    assert x.shape == (2,), x.shape
    return np.sum(x), np.ones_like(x)

check_gradient(array_sum, np.array([3.0, 2.0]))

def array_2d_sum(x):
    assert x.shape == (2,2)
    return np.sum(x), np.ones_like(x)

check_gradient(array_2d_sum, np.array([[3.0, 2.0], [1.0, 0.0]]))
# Out:
# Gradient check passed!
# Gradient check passed!
# Gradient check passed!
# True

# %% [markdown]
# ## Начинаем писать свои функции, считающие аналитический градиент
#
# Теперь реализуем функцию softmax, которая получает на вход оценки для каждого класса и преобразует их в вероятности от 0 до 1:
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/e348290cf48ddbb6e9a6ef4e39363568b67c09d3)
#
# **Важно:** Практический аспект вычисления этой функции заключается в том, что в ней учавствует вычисление экспоненты от потенциально очень больших чисел - это может привести к очень большим значениям в числителе и знаменателе за пределами диапазона float.
#
# К счастью, у этой проблемы есть простое решение -- перед вычислением softmax вычесть из всех оценок максимальное значение среди всех оценок:
# ```
# predictions -= np.max(predictions)
# ```
# (подробнее здесь - http://cs231n.github.io/linear-classify/#softmax, секция `Practical issues: Numeric stability`)

# %%
# TODO Implement softmax and cross-entropy for single sample
probs = linear_classifer.softmax(np.array([-10, 0, 10]))

# Make sure it works for big numbers too!
probs = linear_classifer.softmax(np.array([1000, 0, 0]))
assert np.isclose(probs[0], 1.0)

# %% [markdown]
# Кроме этого, мы реализуем cross-entropy loss, которую мы будем использовать как функцию ошибки (error function).
# В общем виде cross-entropy определена следующим образом:
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/0cb6da032ab424eefdca0884cd4113fe578f4293)
#
# где x - все классы, p(x) - истинная вероятность принадлежности сэмпла классу x, а q(x) - вероятность принадлежности классу x, предсказанная моделью.
# В нашем случае сэмпл принадлежит только одному классу, индекс которого передается функции. Для него p(x) равна 1, а для остальных классов - 0.
#
# Это позволяет реализовать функцию проще!

# %%
probs = linear_classifer.softmax(np.array([-5, 0, 5]))
linear_classifer.cross_entropy_loss(probs, 1)
# Out:
# (5.006760443547122, array([[1]]))

# %% [markdown]
# После того как мы реализовали сами функции, мы можем реализовать градиент.
#
# Оказывается, что вычисление градиента становится гораздо проще, если объединить эти функции в одну, которая сначала вычисляет вероятности через softmax, а потом использует их для вычисления функции ошибки через cross-entropy loss.
#
# Эта функция `softmax_with_cross_entropy` будет возвращает и значение ошибки, и градиент по входным параметрам. Мы проверим корректность реализации с помощью `check_gradient`.

# %%
# TODO Implement combined function or softmax and cross entropy and produces gradient
loss, grad = linear_classifer.softmax_with_cross_entropy(np.array([1, 0, 0]), 1)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, 1), np.array([1, 0, 0], np.float))
# Out:
# Gradient check passed!
# True

# %% [markdown]
# В качестве метода тренировки мы будем использовать стохастический градиентный спуск (stochastic gradient descent или SGD), который работает с батчами сэмплов.
#
# Поэтому все наши фукнции будут получать не один пример, а батч, то есть входом будет не вектор из `num_classes` оценок, а матрица размерности `batch_size, num_classes`. Индекс примера в батче всегда будет первым измерением.
#
# Следующий шаг - переписать наши функции так, чтобы они поддерживали батчи.
#
# Финальное значение функции ошибки должно остаться числом, и оно равно среднему значению ошибки среди всех примеров в батче.

# %%
# TODO Extend combined function so it can receive a 2d array with batch of samples
np.random.seed(42)
# Test batch_size = 1
num_classes = 4
batch_size = 1
predictions = np.random.randint(-1, 3, size=(batch_size, num_classes)).astype(np.float)
target_index = np.random.randint(0, num_classes, size=(batch_size, 1)).astype(np.int)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, target_index), predictions)

# Test batch_size = 3
num_classes = 4
batch_size = 3
predictions = np.random.randint(-1, 3, size=(batch_size, num_classes)).astype(np.float)
target_index = np.random.randint(0, num_classes, size=(batch_size, 1)).astype(np.int)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, target_index), predictions)

# Make sure maximum subtraction for numberic stability is done separately for every sample in the batch
probs = linear_classifer.softmax(np.array([[20,0,0], [1000, 0, 0]]))
assert np.all(np.isclose(probs[:, 0], 1.0))
# Out:
# Gradient check passed!
# Gradient check passed!

# %% [markdown]
# ### Наконец, реализуем сам линейный классификатор!
#
# softmax и cross-entropy получают на вход оценки, которые выдает линейный классификатор.
#
# Он делает это очень просто: для каждого класса есть набор весов, на которые надо умножить пиксели картинки и сложить. Получившееся число и является оценкой класса, идущей на вход softmax.
#
# Таким образом, линейный классификатор можно представить как умножение вектора с пикселями на матрицу W размера `num_features, num_classes`. Такой подход легко расширяется на случай батча векторов с пикселями X размера `batch_size, num_features`:
#
# `predictions = X * W`, где `*` - матричное умножение.
#
# Реализуйте функцию подсчета линейного классификатора и градиентов по весам `linear_softmax` в файле `linear_classifer.py`

# %%
# TODO Implement linear_softmax function that uses softmax with cross-entropy for linear classifier
batch_size = 2
num_classes = 2
num_features = 3
np.random.seed(42)
W = np.random.randint(-1, 3, size=(num_features, num_classes)).astype(np.float)
X = np.random.randint(-1, 3, size=(batch_size, num_features)).astype(np.float)
target_index = np.ones(batch_size, dtype=np.int)

loss, dW = linear_classifer.linear_softmax(X, W, target_index)
check_gradient(lambda w: linear_classifer.linear_softmax(X, w, target_index), W)
# Out:
# Gradient check passed!
# True

# %% [markdown]
# ### И теперь регуляризация
#
# Мы будем использовать L2 regularization для весов как часть общей функции ошибки.
#
# Напомним, L2 regularization определяется как
#
# l2_reg_loss = regularization_strength * sum<sub>ij</sub> W[i, j]<sup>2</sup>
#
# Реализуйте функцию для его вычисления и вычисления соотвествующих градиентов.

# %%
# TODO Implement l2_regularization function that implements loss for L2 regularization
linear_classifer.l2_regularization(W, 0.01)
check_gradient(lambda w: linear_classifer.l2_regularization(w, 0.01), W)
# Out:
# Gradient check passed!
# True

# %% [markdown]
# # Тренировка!

# %% [markdown]
# Градиенты в порядке, реализуем процесс тренировки!

# %%
# TODO: Implement LinearSoftmaxClassifier.fit function
classifier = linear_classifer.LinearSoftmaxClassifier()
loss_history = classifier.fit(train_X, train_y, epochs=10, learning_rate=1e-3, batch_size=300, reg=1e1)
# Out:
# Epoch 0, loss: 2.483185
# Epoch 1, loss: 2.355808
# Epoch 2, loss: 2.317918
# Epoch 3, loss: 2.306643
# Epoch 4, loss: 2.303283
# Epoch 5, loss: 2.302284
# Epoch 6, loss: 2.301988
# Epoch 7, loss: 2.301894
# Epoch 8, loss: 2.301869
# Epoch 9, loss: 2.301862

# %%
# let's look at the loss history!
plt.plot(loss_history)

# %%
# Let's check how it performs on validation set
pred = classifier.predict(val_X)
accuracy = multiclass_accuracy(pred, val_y)
print("Accuracy: ", accuracy)

# Now, let's train more and see if it performs better
classifier.fit(train_X, train_y, epochs=100, learning_rate=1e-3, batch_size=300, reg=1e1)
pred = classifier.predict(val_X)
accuracy = multiclass_accuracy(pred, val_y)
print("Accuracy after training for 100 epochs: ", accuracy)
# Out:
# Accuracy:  0.118
# Epoch 0, loss: 2.301854
# Epoch 1, loss: 2.301877
# Epoch 2, loss: 2.301853
# Epoch 3, loss: 2.301860
# Epoch 4, loss: 2.301865
# Epoch 5, loss: 2.301848
# Epoch 6, loss: 2.301895
# Epoch 7, loss: 2.301868
# Epoch 8, loss: 2.301843
# Epoch 9, loss: 2.301859
# Epoch 10, loss: 2.301862
# Epoch 11, loss: 2.301866
# Epoch 12, loss: 2.301856
# Epoch 13, loss: 2.301868
# Epoch 14, loss: 2.301861
# Epoch 15, loss: 2.301872
# Epoch 16, loss: 2.301849
# Epoch 17, loss: 2.301870
# Epoch 18, loss: 2.301865
# Epoch 19, loss: 2.301855
# Epoch 20, loss: 2.301875
# Epoch 21, loss: 2.301850
# Epoch 22, loss: 2.301865
# Epoch 23, loss: 2.301863
# Epoch 24, loss: 2.301865
# Epoch 25, loss: 2.301853
# Epoch 26, loss: 2.301879
# Epoch 27, loss: 2.301849
# Epoch 28, loss: 2.301859
# Epoch 29, loss: 2.301856
# Epoch 30, loss: 2.301858
# Epoch 31, loss: 2.301867
# Epoch 32, loss: 2.301871
# Epoch 33, loss: 2.301860
# Epoch 34, loss: 2.301866
# Epoch 35, loss: 2.301864
# Epoch 36, loss: 2.301859
# Epoch 37, loss: 2.301874
# Epoch 38, loss: 2.301857
# Epoch 39, loss: 2.301864
# Epoch 40, loss: 2.301891
# Epoch 41, loss: 2.301863
# Epoch 42, loss: 2.301860
# Epoch 43, loss: 2.301848
# Epoch 44, loss: 2.301860
# Epoch 45, loss: 2.301861
# Epoch 46, loss: 2.301858
# Epoch 47, loss: 2.301866
# Epoch 48, loss: 2.301894
# Epoch 49, loss: 2.301857
# Epoch 50, loss: 2.301862
# Epoch 51, loss: 2.301865
# Epoch 52, loss: 2.301860
# Epoch 53, loss: 2.301879
# Epoch 54, loss: 2.301864
# Epoch 55, loss: 2.301857
# Epoch 56, loss: 2.301872
# Epoch 57, loss: 2.301868
# Epoch 58, loss: 2.301875
# Epoch 59, loss: 2.301864
# Epoch 60, loss: 2.301861
# Epoch 61, loss: 2.301857
# Epoch 62, loss: 2.301866
# Epoch 63, loss: 2.301851
# Epoch 64, loss: 2.301867
# Epoch 65, loss: 2.301861
# Epoch 66, loss: 2.301867
# Epoch 67, loss: 2.301870
# Epoch 68, loss: 2.301867
# Epoch 69, loss: 2.301870
# Epoch 70, loss: 2.301882
# Epoch 71, loss: 2.301878
# Epoch 72, loss: 2.301868
# Epoch 73, loss: 2.301874
# Epoch 74, loss: 2.301856
# Epoch 75, loss: 2.301855
# Epoch 76, loss: 2.301876
# Epoch 77, loss: 2.301874
# Epoch 78, loss: 2.301877
# Epoch 79, loss: 2.301875
# Epoch 80, loss: 2.301861
# Epoch 81, loss: 2.301854
# Epoch 82, loss: 2.301867
# Epoch 83, loss: 2.301882
# Epoch 84, loss: 2.301865
# Epoch 85, loss: 2.301870
# Epoch 86, loss: 2.301874
# Epoch 87, loss: 2.301868
# Epoch 88, loss: 2.301863
# Epoch 89, loss: 2.301849
# Epoch 90, loss: 2.301863
# Epoch 91, loss: 2.301876
# Epoch 92, loss: 2.301861
# Epoch 93, loss: 2.301882
# Epoch 94, loss: 2.301891
# Epoch 95, loss: 2.301892
# Epoch 96, loss: 2.301876
# Epoch 97, loss: 2.301870
# Epoch 98, loss: 2.301857
# Epoch 99, loss: 2.301864
# Accuracy after training for 100 epochs:  0.136

# %% [markdown]
# ### Как и раньше, используем кросс-валидацию для подбора гиперпараметтов.
#
# В этот раз, чтобы тренировка занимала разумное время, мы будем использовать только одно разделение на тренировочные (training) и проверочные (validation) данные.
#
# Теперь нам нужно подобрать не один, а два гиперпараметра! Не ограничивайте себя изначальными значениями в коде.
# Добейтесь точности более чем **20%** на проверочных данных (validation data).

# %%
num_epochs = 200
batch_size = 300

learning_rates = [1e-1, 1e-2]
reg_strengths = [1e-3, 1e-4, 1e-5]

best_classifier = None
best_val_accuracy = 0

for rate in learning_rates:
    for reg in reg_strengths:
        classifier = linear_classifer.LinearSoftmaxClassifier()
        classifier.fit(train_X, train_y, epochs=100, learning_rate=rate, batch_size=300, reg=reg)
        pred = classifier.predict(val_X)
        accuracy = multiclass_accuracy(pred, val_y)
        if accuracy > best_val_accuracy:
            best_val_accuracy = accuracy
            best_classifier = classifier

        print("Accuracy: ", accuracy)

# TODO use validation set to find the best hyperparameters
# hint: for best results, you might need to try more values for learning rate and regularization strength 
# than provided initially

print('best validation accuracy achieved: %f' % best_val_accuracy)
# Out:
# Epoch 0, loss: 2.283307
# Epoch 1, loss: 2.233276
# Epoch 2, loss: 2.208511
# Epoch 3, loss: 2.190450
# Epoch 4, loss: 2.178936
# Epoch 5, loss: 2.170724
# Epoch 6, loss: 2.163541
# Epoch 7, loss: 2.157257
# Epoch 8, loss: 2.152076
# Epoch 9, loss: 2.150909
# Epoch 10, loss: 2.146917
# Epoch 11, loss: 2.143227
# Epoch 12, loss: 2.136076
# Epoch 13, loss: 2.137304
# Epoch 14, loss: 2.133851
# Epoch 15, loss: 2.130751
# Epoch 16, loss: 2.132460
# Epoch 17, loss: 2.126637
# Epoch 18, loss: 2.125303
# Epoch 19, loss: 2.129331
# Epoch 20, loss: 2.122398
# Epoch 21, loss: 2.121746
# Epoch 22, loss: 2.118990
# Epoch 23, loss: 2.117136
# Epoch 24, loss: 2.116307
# Epoch 25, loss: 2.118230
# Epoch 26, loss: 2.115566
# Epoch 27, loss: 2.113069
# Epoch 28, loss: 2.113175
# Epoch 29, loss: 2.111369
# Epoch 30, loss: 2.111135
# Epoch 31, loss: 2.113352
# Epoch 32, loss: 2.107973
# Epoch 33, loss: 2.111660
# Epoch 34, loss: 2.107142
# Epoch 35, loss: 2.106697
# Epoch 36, loss: 2.105904
# Epoch 37, loss: 2.105506
# Epoch 38, loss: 2.106862
# Epoch 39, loss: 2.107541
# Epoch 40, loss: 2.104115
# Epoch 41, loss: 2.103732
# Epoch 42, loss: 2.101124
# Epoch 43, loss: 2.104854
# Epoch 44, loss: 2.101486
# Epoch 45, loss: 2.099740
# Epoch 46, loss: 2.098128
# Epoch 47, loss: 2.098150
# Epoch 48, loss: 2.099228
# Epoch 49, loss: 2.096852
# Epoch 50, loss: 2.098603
# Epoch 51, loss: 2.097365
# Epoch 52, loss: 2.096102
# Epoch 53, loss: 2.095549
# Epoch 54, loss: 2.098259
# Epoch 55, loss: 2.092858
# Epoch 56, loss: 2.095396
# Epoch 57, loss: 2.096306
# Epoch 58, loss: 2.094356
# Epoch 59, loss: 2.093555
# Epoch 60, loss: 2.091804
# Epoch 61, loss: 2.093670
# Epoch 62, loss: 2.091019
# Epoch 63, loss: 2.089740
# Epoch 64, loss: 2.090769
# Epoch 65, loss: 2.090969
# Epoch 66, loss: 2.091841
# Epoch 67, loss: 2.090997
# Epoch 68, loss: 2.091138
# Epoch 69, loss: 2.091059
# Epoch 70, loss: 2.089171
# Epoch 71, loss: 2.088850
# Epoch 72, loss: 2.091024
# Epoch 73, loss: 2.090523
# Epoch 74, loss: 2.089556
# Epoch 75, loss: 2.088984
# Epoch 76, loss: 2.089852
# Epoch 77, loss: 2.088365
# Epoch 78, loss: 2.087640
# Epoch 79, loss: 2.089368
# Epoch 80, loss: 2.086183
# Epoch 81, loss: 2.086185
# Epoch 82, loss: 2.086902
# Epoch 83, loss: 2.085969
# Epoch 84, loss: 2.087134
# Epoch 85, loss: 2.086607
# Epoch 86, loss: 2.085503
# Epoch 87, loss: 2.087248
# Epoch 88, loss: 2.085988
# Epoch 89, loss: 2.084259
# Epoch 90, loss: 2.083580
# Epoch 91, loss: 2.084128
# Epoch 92, loss: 2.086630
# Epoch 93, loss: 2.084639
# Epoch 94, loss: 2.083207
# Epoch 95, loss: 2.083088
# Epoch 96, loss: 2.083617
# Epoch 97, loss: 2.084285
# Epoch 98, loss: 2.083704
# Epoch 99, loss: 2.083409
# Accuracy:  0.245
# Epoch 0, loss: 2.281887
# Epoch 1, loss: 2.232161
# Epoch 2, loss: 2.205755
# Epoch 3, loss: 2.189260
# Epoch 4, loss: 2.175158
# Epoch 5, loss: 2.166624
# Epoch 6, loss: 2.164185
# Epoch 7, loss: 2.155336
# Epoch 8, loss: 2.149434
# Epoch 9, loss: 2.144780
# Epoch 10, loss: 2.138879
# Epoch 11, loss: 2.138839
# Epoch 12, loss: 2.132842
# Epoch 13, loss: 2.130486
# Epoch 14, loss: 2.125949
# Epoch 15, loss: 2.126142
# Epoch 16, loss: 2.120302
# Epoch 17, loss: 2.121332
# Epoch 18, loss: 2.116220
# Epoch 19, loss: 2.113885
# Epoch 20, loss: 2.117587
# Epoch 21, loss: 2.111148
# Epoch 22, loss: 2.110134
# Epoch 23, loss: 2.110367
# Epoch 24, loss: 2.106471
# Epoch 25, loss: 2.108788
# Epoch 26, loss: 2.102324
# Epoch 27, loss: 2.103737
# Epoch 28, loss: 2.101051
# Epoch 29, loss: 2.099688
# Epoch 30, loss: 2.098094
# Epoch 31, loss: 2.098642
# Epoch 32, loss: 2.096927
# Epoch 33, loss: 2.094611
# Epoch 34, loss: 2.092592
# Epoch 35, loss: 2.093755
# Epoch 36, loss: 2.089476
# Epoch 37, loss: 2.090802
# Epoch 38, loss: 2.089035
# Epoch 39, loss: 2.086472
# Epoch 40, loss: 2.086791
# Epoch 41, loss: 2.088850
# Epoch 42, loss: 2.084008
# Epoch 43, loss: 2.082499
# Epoch 44, loss: 2.085547
# Epoch 45, loss: 2.083645
# Epoch 46, loss: 2.080418
# Epoch 47, loss: 2.079683
# Epoch 48, loss: 2.080787
# Epoch 49, loss: 2.079133
# Epoch 50, loss: 2.077356
# Epoch 51, loss: 2.078573
# Epoch 52, loss: 2.079066
# Epoch 53, loss: 2.075854
# Epoch 54, loss: 2.076437
# Epoch 55, loss: 2.074057
# Epoch 56, loss: 2.072034
# Epoch 57, loss: 2.073738
# Epoch 58, loss: 2.072384
# Epoch 59, loss: 2.070782
# Epoch 60, loss: 2.069702
# Epoch 61, loss: 2.069731
# Epoch 62, loss: 2.068221
# Epoch 63, loss: 2.068617
# Epoch 64, loss: 2.067778
# Epoch 65, loss: 2.064737
# Epoch 66, loss: 2.068122
# Epoch 67, loss: 2.065212
# Epoch 68, loss: 2.069011
# Epoch 69, loss: 2.063766
# Epoch 70, loss: 2.063467
# Epoch 71, loss: 2.065357
# Epoch 72, loss: 2.061542
# Epoch 73, loss: 2.062528
# Epoch 74, loss: 2.062440
# Epoch 75, loss: 2.061003
# Epoch 76, loss: 2.058995
# Epoch 77, loss: 2.058605
# Epoch 78, loss: 2.061578
# Epoch 79, loss: 2.055837
# Epoch 80, loss: 2.059635
# Epoch 81, loss: 2.057750
# Epoch 82, loss: 2.055893
# Epoch 83, loss: 2.055823
# Epoch 84, loss: 2.056499
# Epoch 85, loss: 2.055282
# Epoch 86, loss: 2.053675
# Epoch 87, loss: 2.055032
# Epoch 88, loss: 2.055497
# Epoch 89, loss: 2.052751
# Epoch 90, loss: 2.054109
# Epoch 91, loss: 2.054484
# Epoch 92, loss: 2.053477
# Epoch 93, loss: 2.052172
# Epoch 94, loss: 2.052388
# Epoch 95, loss: 2.052816
# Epoch 96, loss: 2.054411
# Epoch 97, loss: 2.050170
# Epoch 98, loss: 2.047765
# Epoch 99, loss: 2.048744
# Accuracy:  0.252
# Epoch 0, loss: 2.283170
# Epoch 1, loss: 2.232120
# Epoch 2, loss: 2.207247
# Epoch 3, loss: 2.188387
# Epoch 4, loss: 2.180654
# Epoch 5, loss: 2.167459
# Epoch 6, loss: 2.159510
# Epoch 7, loss: 2.153815
# Epoch 8, loss: 2.150510
# Epoch 9, loss: 2.144100
# Epoch 10, loss: 2.137775
# Epoch 11, loss: 2.136440
# Epoch 12, loss: 2.133132
# Epoch 13, loss: 2.127972
# Epoch 14, loss: 2.128700
# Epoch 15, loss: 2.123998
# Epoch 16, loss: 2.121674
# Epoch 17, loss: 2.119836
# Epoch 18, loss: 2.116409
# Epoch 19, loss: 2.118362
# Epoch 20, loss: 2.111667
# Epoch 21, loss: 2.108853
# Epoch 22, loss: 2.108999
# Epoch 23, loss: 2.106046
# Epoch 24, loss: 2.105829
# Epoch 25, loss: 2.106371
# Epoch 26, loss: 2.100940
# Epoch 27, loss: 2.102655
# Epoch 28, loss: 2.098513
# Epoch 29, loss: 2.098320
# Epoch 30, loss: 2.096616
# Epoch 31, loss: 2.096518
# Epoch 32, loss: 2.094301
# Epoch 33, loss: 2.092116
# Epoch 34, loss: 2.091202
# Epoch 35, loss: 2.090958
# Epoch 36, loss: 2.087683
# Epoch 37, loss: 2.089002
# Epoch 38, loss: 2.088198
# Epoch 39, loss: 2.086203
# Epoch 40, loss: 2.084528
# Epoch 41, loss: 2.084816
# Epoch 42, loss: 2.082765
# Epoch 43, loss: 2.082575
# Epoch 44, loss: 2.084040
# Epoch 45, loss: 2.080200
# Epoch 46, loss: 2.079579
# Epoch 47, loss: 2.079116
# Epoch 48, loss: 2.078339
# Epoch 49, loss: 2.075118
# Epoch 50, loss: 2.075483
# Epoch 51, loss: 2.074959
# Epoch 52, loss: 2.072901
# Epoch 53, loss: 2.074422
# Epoch 54, loss: 2.070614
# Epoch 55, loss: 2.072209
# Epoch 56, loss: 2.071403
# Epoch 57, loss: 2.070344
# Epoch 58, loss: 2.068286
# Epoch 59, loss: 2.067170
# Epoch 60, loss: 2.067086
# Epoch 61, loss: 2.069892
# Epoch 62, loss: 2.067631
# Epoch 63, loss: 2.067663
# Epoch 64, loss: 2.063654
# Epoch 65, loss: 2.064876
# Epoch 66, loss: 2.064230
# Epoch 67, loss: 2.061786
# Epoch 68, loss: 2.060212
# Epoch 69, loss: 2.062397
# Epoch 70, loss: 2.061882
# Epoch 71, loss: 2.062098
# Epoch 72, loss: 2.060137
# Epoch 73, loss: 2.058146
# Epoch 74, loss: 2.059447
# Epoch 75, loss: 2.058623
# Epoch 76, loss: 2.058376
# Epoch 77, loss: 2.057361
# Epoch 78, loss: 2.057331
# Epoch 79, loss: 2.057474
# Epoch 80, loss: 2.055358
# Epoch 81, loss: 2.054331
# Epoch 82, loss: 2.055320
# Epoch 83, loss: 2.052024
# Epoch 84, loss: 2.051854
# Epoch 85, loss: 2.051050
# Epoch 86, loss: 2.052756
# Epoch 87, loss: 2.050451
# Epoch 88, loss: 2.052503
# Epoch 89, loss: 2.049756
# Epoch 90, loss: 2.048065
# Epoch 91, loss: 2.050039
# Epoch 92, loss: 2.048650
# Epoch 93, loss: 2.050182
# Epoch 94, loss: 2.045080
# Epoch 95, loss: 2.044842
# Epoch 96, loss: 2.047138
# Epoch 97, loss: 2.043507
# Epoch 98, loss: 2.046021
# Epoch 99, loss: 2.045533
# Accuracy:  0.239
# Epoch 0, loss: 2.299342
# Epoch 1, loss: 2.290841
# Epoch 2, loss: 2.283068
# Epoch 3, loss: 2.275925
# Epoch 4, loss: 2.269321
# Epoch 5, loss: 2.263080
# Epoch 6, loss: 2.257084
# Epoch 7, loss: 2.251513
# Epoch 8, loss: 2.246605
# Epoch 9, loss: 2.241666
# Epoch 10, loss: 2.236937
# Epoch 11, loss: 2.232878
# Epoch 12, loss: 2.228603
# Epoch 13, loss: 2.224775
# Epoch 14, loss: 2.220977
# Epoch 15, loss: 2.217612
# Epoch 16, loss: 2.214298
# Epoch 17, loss: 2.211359
# Epoch 18, loss: 2.208319
# Epoch 19, loss: 2.205607
# Epoch 20, loss: 2.202605
# Epoch 21, loss: 2.200378
# Epoch 22, loss: 2.198128
# Epoch 23, loss: 2.195592
# Epoch 24, loss: 2.193540
# Epoch 25, loss: 2.191376
# Epoch 26, loss: 2.189578
# Epoch 27, loss: 2.187618
# Epoch 28, loss: 2.185774
# Epoch 29, loss: 2.183990
# Epoch 30, loss: 2.182466
# Epoch 31, loss: 2.180680
# Epoch 32, loss: 2.179189
# Epoch 33, loss: 2.177864
# Epoch 34, loss: 2.176480
# Epoch 35, loss: 2.174890
# Epoch 36, loss: 2.173685
# Epoch 37, loss: 2.172311
# Epoch 38, loss: 2.171308
# Epoch 39, loss: 2.169871
# Epoch 40, loss: 2.168841
# Epoch 41, loss: 2.167660
# Epoch 42, loss: 2.166749
# Epoch 43, loss: 2.165663
# Epoch 44, loss: 2.164845
# Epoch 45, loss: 2.163564
# Epoch 46, loss: 2.162617
# Epoch 47, loss: 2.161823
# Epoch 48, loss: 2.160782
# Epoch 49, loss: 2.159887
# Epoch 50, loss: 2.159044
# Epoch 51, loss: 2.158367
# Epoch 52, loss: 2.157601
# Epoch 53, loss: 2.156723
# Epoch 54, loss: 2.155864
# Epoch 55, loss: 2.155373
# Epoch 56, loss: 2.154635
# Epoch 57, loss: 2.153695
# Epoch 58, loss: 2.153084
# Epoch 59, loss: 2.152228
# Epoch 60, loss: 2.151699
# Epoch 61, loss: 2.151090
# Epoch 62, loss: 2.150469
# Epoch 63, loss: 2.149787
# Epoch 64, loss: 2.149092
# Epoch 65, loss: 2.148406
# Epoch 66, loss: 2.148042
# Epoch 67, loss: 2.147424
# Epoch 68, loss: 2.146759
# Epoch 69, loss: 2.146292
# Epoch 70, loss: 2.145481
# Epoch 71, loss: 2.145145
# Epoch 72, loss: 2.144627
# Epoch 73, loss: 2.143993
# Epoch 74, loss: 2.143448
# Epoch 75, loss: 2.142962
# Epoch 76, loss: 2.142294
# Epoch 77, loss: 2.142065
# Epoch 78, loss: 2.141511
# Epoch 79, loss: 2.141176
# Epoch 80, loss: 2.140541
# Epoch 81, loss: 2.140296
# Epoch 82, loss: 2.139649
# Epoch 83, loss: 2.139141
# Epoch 84, loss: 2.138757
# Epoch 85, loss: 2.138511
# Epoch 86, loss: 2.138048
# Epoch 87, loss: 2.137433
# Epoch 88, loss: 2.137186
# Epoch 89, loss: 2.136689
# Epoch 90, loss: 2.136253
# Epoch 91, loss: 2.135913
# Epoch 92, loss: 2.135355
# Epoch 93, loss: 2.135126
# Epoch 94, loss: 2.134693
# Epoch 95, loss: 2.134250
# Epoch 96, loss: 2.133983
# Epoch 97, loss: 2.133520
# Epoch 98, loss: 2.133323
# Epoch 99, loss: 2.132846
# Accuracy:  0.24
# Epoch 0, loss: 2.299443
# Epoch 1, loss: 2.291001
# Epoch 2, loss: 2.283089
# Epoch 3, loss: 2.275747
# Epoch 4, loss: 2.269500
# Epoch 5, loss: 2.262789
# Epoch 6, loss: 2.257125
# Epoch 7, loss: 2.251374
# Epoch 8, loss: 2.246178
# Epoch 9, loss: 2.241322
# Epoch 10, loss: 2.236837
# Epoch 11, loss: 2.232517
# Epoch 12, loss: 2.228130
# Epoch 13, loss: 2.224136
# Epoch 14, loss: 2.220648
# Epoch 15, loss: 2.217231
# Epoch 16, loss: 2.213778
# Epoch 17, loss: 2.210819
# Epoch 18, loss: 2.207848
# Epoch 19, loss: 2.204829
# Epoch 20, loss: 2.202140
# Epoch 21, loss: 2.199666
# Epoch 22, loss: 2.197092
# Epoch 23, loss: 2.194769
# Epoch 24, loss: 2.192200
# Epoch 25, loss: 2.190175
# Epoch 26, loss: 2.188200
# Epoch 27, loss: 2.186437
# Epoch 28, loss: 2.184616
# Epoch 29, loss: 2.182565
# Epoch 30, loss: 2.181017
# Epoch 31, loss: 2.179329
# Epoch 32, loss: 2.177772
# Epoch 33, loss: 2.176139
# Epoch 34, loss: 2.174726
# Epoch 35, loss: 2.173385
# Epoch 36, loss: 2.171920
# Epoch 37, loss: 2.170876
# Epoch 38, loss: 2.169393
# Epoch 39, loss: 2.168170
# Epoch 40, loss: 2.166737
# Epoch 41, loss: 2.165983
# Epoch 42, loss: 2.164644
# Epoch 43, loss: 2.163686
# Epoch 44, loss: 2.162552
# Epoch 45, loss: 2.161568
# Epoch 46, loss: 2.160350
# Epoch 47, loss: 2.159403
# Epoch 48, loss: 2.158481
# Epoch 49, loss: 2.157685
# Epoch 50, loss: 2.156964
# Epoch 51, loss: 2.155845
# Epoch 52, loss: 2.154954
# Epoch 53, loss: 2.154311
# Epoch 54, loss: 2.153292
# Epoch 55, loss: 2.152755
# Epoch 56, loss: 2.151800
# Epoch 57, loss: 2.150893
# Epoch 58, loss: 2.150221
# Epoch 59, loss: 2.149550
# Epoch 60, loss: 2.148780
# Epoch 61, loss: 2.148081
# Epoch 62, loss: 2.147400
# Epoch 63, loss: 2.146850
# Epoch 64, loss: 2.146075
# Epoch 65, loss: 2.145400
# Epoch 66, loss: 2.144659
# Epoch 67, loss: 2.144172
# Epoch 68, loss: 2.143603
# Epoch 69, loss: 2.142904
# Epoch 70, loss: 2.142303
# Epoch 71, loss: 2.141830
# Epoch 72, loss: 2.141152
# Epoch 73, loss: 2.140762
# Epoch 74, loss: 2.140025
# Epoch 75, loss: 2.139445
# Epoch 76, loss: 2.138955
# Epoch 77, loss: 2.138244
# Epoch 78, loss: 2.137999
# Epoch 79, loss: 2.137312
# Epoch 80, loss: 2.136867
# Epoch 81, loss: 2.136240
# Epoch 82, loss: 2.135895
# Epoch 83, loss: 2.135335
# Epoch 84, loss: 2.134847
# Epoch 85, loss: 2.134356
# Epoch 86, loss: 2.134144
# Epoch 87, loss: 2.133434
# Epoch 88, loss: 2.133155
# Epoch 89, loss: 2.132581
# Epoch 90, loss: 2.132028
# Epoch 91, loss: 2.131652
# Epoch 92, loss: 2.131092
# Epoch 93, loss: 2.130775
# Epoch 94, loss: 2.130125
# Epoch 95, loss: 2.130108
# Epoch 96, loss: 2.129496
# Epoch 97, loss: 2.129012
# Epoch 98, loss: 2.128721
# Epoch 99, loss: 2.128372
# Accuracy:  0.245
# Epoch 0, loss: 2.299056
# Epoch 1, loss: 2.290590
# Epoch 2, loss: 2.282735
# Epoch 3, loss: 2.275766
# Epoch 4, loss: 2.269074
# Epoch 5, loss: 2.262670
# Epoch 6, loss: 2.256765
# Epoch 7, loss: 2.251342
# Epoch 8, loss: 2.245893
# Epoch 9, loss: 2.241111
# Epoch 10, loss: 2.236656
# Epoch 11, loss: 2.232134
# Epoch 12, loss: 2.228081
# Epoch 13, loss: 2.224200
# Epoch 14, loss: 2.220337
# Epoch 15, loss: 2.216779
# Epoch 16, loss: 2.213613
# Epoch 17, loss: 2.210283
# Epoch 18, loss: 2.207530
# Epoch 19, loss: 2.204669
# Epoch 20, loss: 2.201828
# Epoch 21, loss: 2.199580
# Epoch 22, loss: 2.196623
# Epoch 23, loss: 2.194612
# Epoch 24, loss: 2.192420
# Epoch 25, loss: 2.190279
# Epoch 26, loss: 2.188014
# Epoch 27, loss: 2.186069
# Epoch 28, loss: 2.184325
# Epoch 29, loss: 2.182620
# Epoch 30, loss: 2.180780
# Epoch 31, loss: 2.179135
# Epoch 32, loss: 2.177650
# Epoch 33, loss: 2.175848
# Epoch 34, loss: 2.174555
# Epoch 35, loss: 2.173017
# Epoch 36, loss: 2.171798
# Epoch 37, loss: 2.170271
# Epoch 38, loss: 2.169172
# Epoch 39, loss: 2.167933
# Epoch 40, loss: 2.166838
# Epoch 41, loss: 2.165563
# Epoch 42, loss: 2.164435
# Epoch 43, loss: 2.163469
# Epoch 44, loss: 2.162266
# Epoch 45, loss: 2.161205
# Epoch 46, loss: 2.160335
# Epoch 47, loss: 2.159134
# Epoch 48, loss: 2.158517
# Epoch 49, loss: 2.157210
# Epoch 50, loss: 2.156505
# Epoch 51, loss: 2.155533
# Epoch 52, loss: 2.154759
# Epoch 53, loss: 2.153773
# Epoch 54, loss: 2.153143
# Epoch 55, loss: 2.152261
# Epoch 56, loss: 2.151671
# Epoch 57, loss: 2.150588
# Epoch 58, loss: 2.150076
# Epoch 59, loss: 2.149187
# Epoch 60, loss: 2.148413
# Epoch 61, loss: 2.147646
# Epoch 62, loss: 2.147193
# Epoch 63, loss: 2.146402
# Epoch 64, loss: 2.145812
# Epoch 65, loss: 2.145010
# Epoch 66, loss: 2.144468
# Epoch 67, loss: 2.143851
# Epoch 68, loss: 2.143091
# Epoch 69, loss: 2.142627
# Epoch 70, loss: 2.141982
# Epoch 71, loss: 2.141208
# Epoch 72, loss: 2.140658
# Epoch 73, loss: 2.140262
# Epoch 74, loss: 2.139548
# Epoch 75, loss: 2.139094
# Epoch 76, loss: 2.138435
# Epoch 77, loss: 2.138078
# Epoch 78, loss: 2.137714
# Epoch 79, loss: 2.136763
# Epoch 80, loss: 2.136407
# Epoch 81, loss: 2.135965
# Epoch 82, loss: 2.135215
# Epoch 83, loss: 2.135017
# Epoch 84, loss: 2.134493
# Epoch 85, loss: 2.133761
# Epoch 86, loss: 2.133412
# Epoch 87, loss: 2.132975
# Epoch 88, loss: 2.132587
# Epoch 89, loss: 2.132131
# Epoch 90, loss: 2.131526
# Epoch 91, loss: 2.131140
# Epoch 92, loss: 2.130755
# Epoch 93, loss: 2.130454
# Epoch 94, loss: 2.130003
# Epoch 95, loss: 2.129464
# Epoch 96, loss: 2.129046
# Epoch 97, loss: 2.128567
# Epoch 98, loss: 2.128147
# Epoch 99, loss: 2.127888
# Accuracy:  0.24
# best validation accuracy achieved: 0.252000

# %% [markdown]
# # Какой же точности мы добились на тестовых данных?

# %%
test_pred = best_classifier.predict(test_X)
test_accuracy = multiclass_accuracy(test_pred, test_y)
print('Linear softmax classifier test set accuracy: %f' % (test_accuracy, ))
# Out:
# Linear softmax classifier test set accuracy: 0.198000
